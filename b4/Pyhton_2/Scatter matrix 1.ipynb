# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import parallel_coordinates

# %%
df=pd.read_csv('auto-mpg1.csv')

# %%
pd.plotting.scatter_matrix(df,figsize=[15,15],marker='v',alpha=0.5,diagonal='kde')
plt.show()

# %%
df=pd.read_csv('auto-mpg.csv')

# %%
pll=parallel_coordinates(df,'displacement',cols=['acceleration','mpg','origin'],color=['red','green','blue','yellow','black'])
