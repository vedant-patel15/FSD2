# %%
import pandas as pd

marks={'ram':55,'shyam':60,'seeta':70,'geeta':65}
marks_series=pd.Series(marks,name="Student Results")

print(marks_series)
# Out:
# ram      55
# shyam    60
# seeta    70
# geeta    65
# Name: Student Results, dtype: int64

# %%
list(marks_series)
# Out:
# [55, 60, 70, 65]

# %%
dict(marks_series)
# Out:
# {'ram': 55, 'shyam': 60, 'seeta': 70, 'geeta': 65}

# %%
marks_series[1]=100

marks_series
# Out:
# ram       55
# shyam    100
# seeta     70
# geeta     65
# Name: Student Results, dtype: int64

# %%
100+marks_series
# Out:
# ram      155
# shyam    200
# seeta    170
# geeta    165
# Name: Student Results, dtype: int64

# %%
marks_series
# Out:
# ram       55
# shyam    100
# seeta     70
# geeta     65
# Name: Student Results, dtype: int64

# %%
marks_series>=100
# Out:
# ram      False
# shyam     True
# seeta    False
# geeta    False
# Name: Student Results, dtype: bool

# %%
import pandas as pd

a=pd.Series([2,4,6,8,10])
b=pd.Series([1,3,5,7,10])

# %%
a+b
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    20
# dtype: int64

# %%
a-b
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: int64

# %%
a*b
# Out:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    100
# dtype: int64

# %%
a/b
# Out:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.000000
# dtype: float64

# %%
a==b
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
a>b
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %%
a<b
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
