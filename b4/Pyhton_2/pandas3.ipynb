# %%
import pandas as pd

bw=pd.read_csv("bollywood.csv",index_col="movie").squeeze()

print(bw)
print(bw.describe())
print(bw.head(10))
print(bw.tail(10))
print(bw[0])
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object
# count             1500
# unique             566
# top       Akshay Kumar
# freq                48
# Name: lead, dtype: object
# movie
# Uri: The Surgical Strike                       Vicky Kaushal
# Battalion 609                                    Vicky Ahuja
# ...

# %%
print(bw[-5:])
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
print(bw[::2])
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
print(bw[[0,1,3,4,8]])
# Out:
# movie
# Uri: The Surgical Strike               Vicky Kaushal
# Battalion 609                            Vicky Ahuja
# Why Cheat India                        Emraan Hashmi
# Evening Shadows                     Mona Ambegaonkar
# Manikarnika: The Queen of Jhansi      Kangana Ranaut
# Name: lead, dtype: object

# %%
"Alia Bhatt" in bw.values
# Out:
# True

# %%
"Why Cheat India" in bw
# Out:
# True

# %%
bw.value_counts()
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Himanshu Malik       1
# Rajat Barmecha       1
# Saahil Chadha        1
# Vikaas Kalantari     1
# Abhishek Bharate     1
# Name: lead, Length: 566, dtype: int64

# %%
bw.value_counts(ascending=True)
# Out:
# Abhishek Bharate     1
# Vikaas Kalantari     1
# Saahil Chadha        1
# Rajat Barmecha       1
# Himanshu Malik       1
#                     ..
# Sanjay Dutt         26
# Salman Khan         31
# Ajay Devgn          38
# Amitabh Bachchan    45
# Akshay Kumar        48
# Name: lead, Length: 566, dtype: int64

# %%
x=bw.value_counts()
print(x[x>20])
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: lead, dtype: int64

# %%
bw[bw.values=="Akshay Kumar"].size
# Out:
# 48

# %%
x["Akshay Kumar"]
# Out:
# 48
